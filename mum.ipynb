# %%
x = 3050
y = 5550
z = 2150
v = 950
print(x%100)
total = 12.1*x + 60.24*y + 48.4*z + 84.36*v
print(total)
if(total == 538810):
    print(x,y,z,v)
for s in range(150):
    x = x+1
    y = 5550
    z = 2150
    v = 950
    for i in range(150):
        y = y+1
        z = 2150
        v = 950
        for j in range(150):
            z = z+1
            v = 950
            for k in range(150):
                v = v + 1
                total = 12.1*x + 60.24*y + 48.4*z + 84.36*v
                if(total == 566433.96 and (x%100 > 50) and (y%100 > 50) and (z%100 > 50) and (v%100 > 50)):
                    if((x%2 == 0) and (y%2 == 0) and (z%2 == 0) and (v%2 == 0)):
                        print(total)
                        print(x,y,z,v)
print("end")
# Out:
# 50
# 555439.0
# 566433.96
# 3058 5562 2294 988
# 566433.96
# 3058 5676 2180 972
# 566433.96
# 3062 5596 2296 962
# 566433.96
# 3066 5562 2292 988
# 566433.96
# 3066 5676 2178 972
# 566433.96
# 3070 5596 2294 962
# 566433.96
# 3074 5562 2290 988
# 566433.96
# 3078 5596 2292 962
# 566433.96
# 3082 5562 2288 988
# 566433.96
# 3082 5676 2174 972
# 566433.96
# 3086 5596 2290 962
# 566433.96
# 3090 5562 2286 988
# 566433.96
# 3090 5676 2172 972
# 566433.96
# 3098 5562 2284 988
# 566433.96
# 3098 5676 2170 972
# 566433.96
# 3154 5562 2270 988
# 566433.96
# 3158 5596 2272 962
# 566433.96
# 3162 5562 2268 988
# 566433.96
# 3162 5676 2154 972
# 566433.96
# 3166 5596 2270 962
# 566433.96
# 3170 5562 2266 988
# 566433.96
# 3170 5676 2152 972
# 566433.96
# 3178 5562 2264 988
# 566433.96
# 3182 5596 2266 962
# 566433.96
# 3186 5562 2262 988
# 566433.96
# 3190 5596 2264 962
# 566433.96
# 3194 5562 2260 988
# 566433.96
# 3198 5596 2262 962
# end
